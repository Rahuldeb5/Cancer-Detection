# %%
import pandas as pd

df = pd.read_csv("data/pants - PanTS_metadata (1).csv")
df.head()

# %% [markdown]
# ### a) Rows where "tumor?" is nonzero/non-empty

# %%
tumor_nonzero = df["tumor?"].notna() & (df["tumor?"] != 0)
tumor_nonzero.sum()

# %% [markdown]
# ### b) Distribution of "age" and "sex"

# %%
df["age"].describe()

# %%
df["age"].hist(bins=30)

# %%
df["sex"].value_counts(dropna=False)

# %% [markdown]
# ### c) Count of each "ct phase"

# %%
df["ct phase"].value_counts(dropna=False)

# %% [markdown]
# ### d) Types of "study type" and counts

# %%
df["study type"].value_counts(dropna=False)
